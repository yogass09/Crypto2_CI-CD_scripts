# %%
import pyodbc

# Define connection parameters
server = 'cp-io-sql.database.windows.net'
database = 'sql_db_ohlcv'
username = 'yogass09'
password = 'Qwerty@312'
driver = 'ODBC Driver 17 for SQL Server'
port = 1433

# Establish the connection
conn = pyodbc.connect(
    f'DRIVER={driver};SERVER={server},{port};DATABASE={database};UID={username};PWD={password}'
)

# Create a cursor object
cursor = conn.cursor()

# Define the SQL query to fetch the slug column
query = 'SELECT slug FROM [dbo].[crypto.list]'

# Execute the query
cursor.execute(query)

# Fetch all results
slugs = cursor.fetchall()

# Process the results to create a list of slugs
slug_list = [slug[0] for slug in slugs]

# Create a comma-separated string of slugs
slug_csv = ','.join(slug_list)

# Print the comma-separated list of slugs
print(slug_csv)

# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# tigercoin,memorycoin,earthcoin,fedoracoin,dimecoin,ybcoin,extremecoin,etoken,grain,particle,klondikecoin,kittehcoin,redcoin,astrocoin,velocitycoin,battlecoin,leafcoin,starcoin,usde,pxlcoin,smartcoin,teslacoin,applecoin,karmacoin,nyancoin,ultracoin,zenithcoin,blakecoin,unitecoin,dash,cachecoin,topcoin,pennies,icoin,pandacoin-pand,mintcoin,cryptographic-anomaly,penguincoin-old,auroracoin,zedcoin,animecoin,duckduckcoin,microcoin,cagecoin,billioncoin,cashcoin,pandacoin-pnd,orobit,mazacoin,takcoin,frycoin,uniform-fiscal-object,continuumcoin,batcoin,grumpycoin,foxcoin,litebar,photon,murraycoin,thorcoin,globe,zeitcoin,rainbowcoin,dnotes,leprocoin,saturncoin,syncoin,heavycoin,coin2,ebtcoin,noodlyappendagecoin,ekrona,fairquark,einsteinium,heisenberg,zeuscoin,bitcoin-scrypt,coin,emucoin,gpucoin,stockcoin,eccoin,gaelcoin,aphroditecoin,octocoin,metiscoin,faircoin,ghostcoin,pawncoin,solarcoin,e-gulden,macrocoin,neocoin,bonuscoin,deletecoin,rotocoin,hongketocoin,bitleu,educoin,karpelescoin,procoin,cryptoescudo,isracoin,365coin,gulden,surgecoin,polcoin,groestlcoin,lycancoin,plncoin,caix,communitycoin,colbertcoin,nas,asiacoin,hotcoin,cataloniacoin,kashmircoin,popularcoin,bitstar,cannacoin,yellowcoin,cleanwatercoin,speedcoin,global-denomination,diem,logicoin,limecoin,maidsafecoin,cornerstonecoin,zimstake,xxlcoin,sambacoin,universitycoin,virtualminingcoin,vegascoin,canada-ecoin,sharecoin,silkcoin,stories,crtcoin,omnicoin,guncoin,pinkcoin,orangecoin,libertycoin,coffeecoin,yincoin,yangcoin,informationcoin,nautiluscoin,energycoin,vericoin,tekcoin,monero,sync,huskycoin,litecoin-plus,jackpotcoin,curecoin,unbreakablecoin,xcurrency,cryptcoin,mastiffcoin,aimcoin,quarkbar,dirac,qora,globalboost,savecoin,boostcoin,citizencoin,entropycoin,wincoin,bitquark,litecoinx,shopcoin,leaguecoin,digital-commerce,banknote,magicoin,failcoin,kryptkoin,artbyte,vootcoin,mammothcoin,neutrino,mugatucoin,uro,fuelcoin,electron,piggycoin,harmonycoin,startcoin,deprecated-denarius,fractalcoin,mycoin,glyph,talkcoin,goalcoin,wavecoin,bluechip,korecoin,opeccoin,digitalnote,boolberry,nemstake,digit,venividivici,blazecoin,techcoin,roxcoin,bitblock,monetaverde,singularity,ntx,xxxcoin,universecoin,siamesecoin,saturn2coin,lightcoin,conspiracycoin,maiacoin,riotcoin,imperialcoin,judgecoin,ascentcoin,latium-old,californiacoin,ultimatecoin,forexcoin,x14coin,nfdcoin,stealth,icebergcoin,torcoin,n5coin,shield,aegis,chccoin,cscoin,noahcoin,clams,quatloo,xanoncoin,next-horizon,bitcoindark,truckcoin,arcoin,millionairecoin,concealcoin,firecoin,pseudocoin,tacocoin,lion,elitecoin,gbcoin,lottoshares,bitmoney-old,darkcash,esportscoin,bancorcoin,payzorcoin,shadowcash,tomatocoin,iocoin,ringo,altcoin,cryptonite,carboncoin,doomcoin,boom-coin,ekita,incognitocoin,apicoin,librexcoin,eutopium,titcoin,zipcoin,zccoin,groupcoin,revocoin,virtacoin,plutoniumcoin,doscoin,xcloudcoin,hyperstake,cococoin,ethancoin,qibuck,vaultcoin,nxttycoin,blacktoken,mantiscoin,joincoin,clustercoin,syscoin,bitmark,halcyon,new-universal-dollar,darkfox,ltbcoin,bigbullion,xdecoin,captcoin,mgw,greenbacks,usecoin,axron,dogeparty,umbrella-ltc,bitmo,skynet,rabbitcoin,burst,moneta,newworldordercoin,tradercoin,coinomat,prozcoin,shadecoin,native-coin,kimdotcoin,bongger,cinder,ubiq,socialxbot,solcoin,litecoindark,bunnycoin,node,mileycyruscoin,lightspeed,deepcoin,bitcentavo,instantdex,tatianacoin,swarm-old,gnosis,darktoken,mozzshare,supernet,checkcoin,crackcoin,volatilitycoin,rescuecoin,orthocoin,atomic,freemarket,bitusd,bitcny,nubits,sterlingcoin,bct-coin,magi,midascoin,utilitycoin,exclusivecoin,inkwaycoin,pelecoin,ruble,craigscoin,skullcoin,banx,jinn,ethercoin,vortex,maryjane,beavercoin,ach,potatocoin,cryptobuck,dashcoin,archcoin,darkpeer,seedcoin,aurum-coin,nxtinspect,whistlecoin,lemurcoin,kryptonite,dogeblackcoin,bdsm,fetish,czechcrowncoin,miraclecoin,sativacoin,premineplus,dolphincoin,wolfcoin,glowcoin,voxpopuli,mmnxt,spark,ganjacoin,verge,tilecoin,munne,coinworkscoin,nushares,fireflycoin,spreadcoin,rimbit,blocknet,scattercoin,securitysysc ...

# %%
#This example uses Python 2.7 and the python-request library.

from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

# %%
import pyodbc
import requests
import time
import pandas as pd

# Define connection parameters
server = 'cp-io-sql.database.windows.net'
database = 'sql_db_ohlcv'
username = 'yogass09'
password = 'Qwerty@312'
driver = 'ODBC Driver 17 for SQL Server'
port = 1433

# Establish the connection
conn = pyodbc.connect(
    f'DRIVER={driver};SERVER={server},{port};DATABASE={database};UID={username};PWD={password}'
)

# Create a cursor object
cursor = conn.cursor()
# Out:
# C:\Users\44776\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
# Define the SQL query to fetch the slug column
query = 'SELECT slug FROM [dbo].[crypto.list]'

# Execute the query
cursor.execute(query)

# Fetch all results
slugs = cursor.fetchall()

# Process the results to create a list of slugs
slug_list = [slug[0] for slug in slugs]

# Close the cursor and connection
cursor.close()
conn.close()

# Replace with your CoinMarketCap API key
API_KEY = '9d5aff71-7d4b-48f3-9afd-6532c5a1cd69'

# API endpoint
url = 'https://pro-api.coinmarketcap.com/v2/cryptocurrency/info'

# Prepare headers with API key
headers = {
    'X-CMC_PRO_API_KEY': API_KEY
}

# Function to make API requests in batches
def fetch_cryptocurrency_info(slug_batch):
    params = {
        'slug': ','.join(slug_batch),
        'aux': 'urls,logo,description'  # Adjust auxiliary fields as needed
    }
    response = requests.get(url, headers=headers, params=params)
    return response

# Batch size
batch_size = 199  # Adjust the batch size as needed
total_slugs = len(slug_list)

# Initialize an empty list to store the data
all_data = []

# %%
for i in range(0, total_slugs, batch_size):
    slug_batch = slug_list[i:i + batch_size]
    response = fetch_cryptocurrency_info(slug_batch)
    
    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        data = response.json()
        # Extract the relevant data and append to the list
        if 'data' in data:
            for key, value in data['data'].items():
                all_data.append(value)
    else:
        print(f"Error: {response.status_code} - {response.text}")
    
    # Wait for 1 second before the next request
    time.sleep(2)
# Out:
# Error: 403 - <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
# <HTML><HEAD><META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=iso-8859-1">
# <TITLE>ERROR: The request could not be satisfied</TITLE>
# </HEAD><BODY>
# <H1>403 ERROR</H1>
# <H2>The request could not be satisfied.</H2>
# <HR noshade size="1px">
# Request blocked.
# We can't connect to the server for this app or website at this time. There might be too much traffic or a configuration error. Try again later, or contact the app or website owner.
# <BR clear="all">
# If you provide content to customers through CloudFront, you can find steps to troubleshoot and help prevent this error by reviewing the CloudFront documentation.
# <BR clear="all">
# <HR noshade size="1px">
# <PRE>
# Generated by cloudfront (CloudFront)
# Request ID: QJtTGN2FZglggqj3DCDm3NdAVkTwonYlY5xDVHhbD3M-p4cyxo6DJg==
# </PRE>
# <ADDRESS>
# </ADDRESS>
# </BODY></HTML>
# Error: 400 - {"status":{"timestamp":"2024-07-04T14:11:03.095Z","error_code":400,"error_message":"Invalid value for \"slug\": \"baby-cuban\"","elapsed":0,"credit_count":0,"notice":null}}

# %%
# Convert the list of data to a pandas DataFrame
df = pd.DataFrame(all_data)

# Save the DataFrame to a CSV file
df.to_csv('cryptocurrency_info.csv', index=False)

# Print the DataFrame to verify
print(df)
# Out:
#           id                     name   symbol category  \
# 0         79                Tigercoin      TGC     coin
# 1         81               Memorycoin      MMC     coin
# 2         85                EarthCoin      EAC     coin
# 3         87               FedoraCoin     TIPS     coin
# 4         90                 Dimecoin     DIME     coin
# ...      ...                      ...      ...      ...
# 21873  32027  Amnis Staked Aptos coin    STAPT    token
# 21874  32038            Edge Video AI     FAST    token
# 21875  32045                    CHEWY     CHWY    token
# 21876  32054                   TeiTei   TEITEI    token
# 21877  32058     Pink Hood Froglicker  FROGLIC    token
#
#                                              description  \
# 0      Tigercoin (TGC) is a cryptocurrency . Users ar...
# 1      Memorycoin (MMC) is a cryptocurrency . Users a...
# 2      EarthCoin (EAC) is a cryptocurrency . Users ar...
# 3      FedoraCoin (TIPS) is a cryptocurrency . Users ...
# 4      Dimecoin (DIME) is a cryptocurrency launched i...
# ...                                                  ...
# 21873  Amnis Staked Aptos coin (STAPT) is a cryptocur...
# 21874  Edge Video AI (FAST) is a cryptocurrency launc...
# 21875  CHEWY (CHWY) is a cryptocurrency launched in 2...
# 21876  TeiTei (TEITEI) is a cryptocurrency launched i...
# 21877  Pink Hood Froglicker (FROGLIC) is a cryptocurr...
#
#                           slug  \
# 0                    tigercoin
# 1                   memorycoin
# 2                    earthcoin
# 3                   fedoracoin
# 4                     dimecoin
# ...                        ...
# 21873  amnis-staked-aptos-coin
# 21874                     fast
# 21875              chewy-token
# 21876                   teitei
# 21877     pink-hood-froglicker
#
#                                                     logo       subreddit  \
# 0      https://s2.coinmarketcap.com/static/img/coins/...
# 1      https://s2.coinmarketcap.com/static/img/coins/...      memorycoin
# 2      https://s2.coinmarketcap.com/static/img/coins/...       Earthcoin
# 3      https://s2.coinmarketcap.com/static/img/coins/...  FedoraTipsCoin
# 4      https://s2.coinmarketcap.com/static/img/coins/...        dimecoin
# ...                                                  ...             ...
# 21873  https://s2.coinmarketcap.com/static/img/coins/...
# 21874  https://s2.coinmarketcap.com/static/img/coins/...
# 21875  https://s2.coinmarketcap.com/static/img/coins/...
# 21876  https://s2.coinmarketcap.com/static/img/coins/...
# 21877  https://s2.coinmarketcap.com/static/img/coins/...
#
#                                       tag-names  \
# 0                      [Mineable, PoW, SHA-256]
# 1                                    [Mineable]
# 2                                    [Mineable]
# 3                                    [Mineable]
# 4                        [Mineable, PoW, Quark]
# ...                                         ...
# 21873  [Aptos Ecosystem, Rehypothecated Crypto]
# 21874                                      None
# 21875                                      None
# 21876                                      None
# 21877                                      None
#
#                            tag-groups  \
# 0      [OTHERS, ALGORITHM, ALGORITHM]
# 1                            [OTHERS]
# 2                            [OTHERS]
# 3                            [OTHERS]
# 4      [OTHERS, ALGORITHM, ALGORITHM]
# ...                               ...
# 21873            [PLATFORM, CATEGORY]
# 21874                            None
# 21875                            None
# 21876                            None
# 21877                            None
#
#                                                     urls twitter_username  \
# 0      {'website': ['http://tigercoin.wordpress.com']...
# 1      {'website': ['http://memorycoin.org/'], 'twitt...    MemoryCoinMMC
# 2      {'website': ['http://earthcoin.io/'], 'twitter...     getearthcoin
# 3      {'website': ['https://www.tipsco.in/'], 'twitt...   FedoraTipscoin
# 4      {'website': ['https://www.dimecoinnetwork.com/...         Dimecoin
# ...                                                  ...              ...
# 21873  {'website': ['https://amnis.finance/'], 'twitt...     AmnisFinance
# 21874  {'website': ['https://www.edgevideo.ai/'], 'tw...      edgevideoai
# 21875  {'website': ['https://chewy2024.xyz/'], 'twitt...       CHEWY_CHWY
# 21876  {'website': ['https://teitei.fun/'], 'twitter'...        TEITEI_DT
# 21877  {'website': ['https://www.froglic.io/'], 'twit...      FroglicCoin
#
#        is_hidden             date_launched  \
# 0              0                      None
# 1              0                      None
# 2              0                      None
# 3              0                      None
# 4              0  2013-12-23T00:00:00.000Z
# ...          ...                       ...
# 21873          0  2023-10-19T00:00:00.000Z
# 21874          0  2024-06-10T00:00:00.000Z
# 21875          0  2024-06-28T00:00:00.000Z
# 21876          0  2024-06-30T00:00:00.000Z
# 21877          0  2024-06-30T00:00:00.000Z
#
#                                         contract_address  \
# 0                                                     []
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 21873  [{'contract_address': '0x111ae3e5bc816a5e63c2d...
# 21874  [{'contract_address': '0xffBF21632d4AD2B1F8503...
# 21875  [{'contract_address': 'y7WrhyUxATe9xMmdQKGp2pc...
# 21876  [{'contract_address': '0xa4F59D5C14567F346047d...
# 21877  [{'contract_address': '0x4aBD5745F326932B1b673...
#
#        self_reported_circulating_supply  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ...                                 ...
# 21873                      1.070935e+07
# 21874                      2.000000e+07
# 21875                      4.206900e+16
# 21876                      4.206900e+17
# 21877                      1.000000e+10
#
#                                       self_reported_tags  \
# 0                                                   None
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4      [PoS, PoW, Quark, Store Of Value, Masternodes,...
# ...                                                  ...
# 21873                                               None
# 21874                                               None
# 21875                                               None
# 21876                                               None
# 21877                                               None
#
#        self_reported_market_cap  infinite_supply
# 0                           NaN            False
# 1                           NaN            False
# 2                           NaN            False
# 3                           NaN            False
# 4                           NaN            False
# ...                         ...              ...
# 21873              6.894829e+07            False
# 21874              2.647186e+06            False
# 21875              1.333824e+06            False
# 21876              8.718358e+04            False
# 21877              2.110309e+06            False
#
# [21878 rows x 19 columns]

# %%
# Close the cursor and connection
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-9-8dd0cd799055> in <module>
# ----> 1 conn.close()
#
# ProgrammingError: Attempt to use a closed connection.
